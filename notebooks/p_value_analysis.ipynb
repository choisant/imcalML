# %%
#scientific libraries and plotting
import numpy as np
import scipy as scipy
from scipy import stats
from scipy import optimize
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn
from tqdm import tqdm
import math
import os
import random

#other libraries
import sys
from pathlib import Path
from sklearn.metrics import confusion_matrix

# %%
#variables controlled by the user. Change these to fit your specific needs.
RES = 50 #resolution
#LABELS = ["PP13-Sphaleron-THR9-FRZ15-NB0-NSUBPALL", "BH_n4_M8", "BH_n2_M10", "BH_n4_M10", "BH_n6_M10", "BH_n4_M12"]
LABELS = ["PP13-Sphaleron-THR9-FRZ15-NB0-NSUBPALL", "BH_n4_M8", "BH_n2_M10", "BH_n4_M10", "BH_n6_M10", "BH_n4_M12"]
TEST_LABELS = [f"{label}_test" for label in LABELS]
#PLOT_LABELS = ["SPH_9", "BH_n4_M8", "BH_n2_M10", "BH_n4_M10", "BH_n6_M10", "BH_n4_M12"]
PLOT_LABELS = ["SPH_9", "BH_n4_M8", "BH_n2_M10", "BH_n4_M10", "BH_n6_M10", "BH_n4_M12"]

CLASSES = len(LABELS) #The number of output nodes in the net, equal to the number of classes
FOLDERS = ["sph", "BH", "BH", "BH", "BH", "BH"]
TEST_N_EVENTS = 15000
CUT = True
LOAD = True
N_max = 45 #Maximum number of events measured
M = 3000 #Number of experiments to average
STATISTIC = "binomial" # available statistics: ["poisson", "chi2"]

#Set data paths
if CUT:
    N_EVENTS = 15000
    TEST_FILENAMES = [f"{label}_res{RES}_STmin7_Nmin5_15000_events.h5" for label in TEST_LABELS]
else:
    N_EVENTS = 3000
    TEST_FILENAMES = [f"{label}_res{RES}_3000_events.h5" for label in TEST_LABELS]
TEST_DATAPATHS = [f"/disk/atlas3/data_MC/2dhistograms/{FOLDERS[i]}/{RES}/{TEST_FILENAMES[i]}" for i in range(CLASSES)]

LOAD_FOLDER = "../results/predictions/resnet"
MODEL_NAME = "thesis_ensemble"
LOAD_PATH = f"{LOAD_FOLDER}/{MODEL_NAME}.csv"

#paper_colors = ['#4c72b0','#55a868', '#dd8452', '#c44e52',  '#937860', '#8172b3']
paper_colors = ['#4c72b0','#dd8452', '#55a868',  '#c44e52',  '#8172b3', '#937860']
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)
sn.set_theme(context="paper", style="whitegrid", palette=paper_colors, font='sans-serif', color_codes=True, rc=None)

# %%
df = pd.read_csv(LOAD_PATH)
datasets = [0]*CLASSES
for i in range(CLASSES):
    df_temp = df[df["Truth"] == i ]
    datasets[i] = df_temp

# %%
#Print the raw ML outputs before argmax
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(15, 10), layout="constrained", sharex=True, sharey=True)
plt.subplots_adjust(hspace=0.3)
for i in range(CLASSES):
    df_temp = datasets[i]
    for j in range(CLASSES):
        sn.histplot(df_temp[f"{j}"], ax = ax[i%2][i//2], label=f"{PLOT_LABELS[j]}", color=paper_colors[j], binrange=[0, 1], bins=20, 
                    common_norm=False, multiple="layer", fill="False", stat="proportion")
    ax[i%2][i//2].text(0.2, 0.8, f"Estimates on {PLOT_LABELS[i]}", fontsize=18, bbox=dict(facecolor='white', edgecolor='grey'))
    ax[i%2][i//2].set_ylim(0, 1)
    ax[i%2][i//2].set_xlim(-0.05, 1.05)
    ax[i%2][i//2].set_ylabel("Fraction of events", fontsize=16)
    ax[i%2][i//2].set_xlabel("Estimated class probability", fontsize=16)
    ax[i%2][i//2].tick_params(which="major", direction="out", bottom=True, left=True, pad=5, length=6, width=1, labelsize=14)

fig.suptitle(f"      ", x=0.1, va="top", fontsize=40)
handles, labels = ax[0][0].get_legend_handles_labels()
#labels = [fr"{hue_key} = {label}" for label in labels]
fig.legend(handles, labels, loc='upper center', ncol=6, labelspacing=0.1, fontsize=16, frameon=True)
# Out:
# /tmp/ipykernel_10615/2871090705.py:3: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.subplots_adjust(hspace=0.3)

# %%
#Print the classifications (argmax)
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(15, 10), layout="constrained", sharex=False, sharey=True)
for i in range(CLASSES):
    df_temp = datasets[i]
    sn.histplot(df_temp["Prediction"], binrange=[-0.5, CLASSES-0.5], bins=CLASSES, ax = axs[i%2][i//2], color=paper_colors[i],
                stat="proportion")
    axs[i%2][i//2].set_title(f"Predictions on {PLOT_LABELS[i]}", fontsize=16)

for ax in axs.flatten():
    #ax.set_xlabel("Confidence", fontsize=16)
    ax.set_ylabel("Fraction of events", fontsize=16)
    ax.set_xlabel("Output", fontsize=16)
    ax.set_xticks(np.arange(0, CLASSES), PLOT_LABELS, rotation=60, fontsize=14)
    ax.tick_params(which="major", direction="out", bottom=True, left=True, pad=5, length=6, width=1, labelsize=14)
    ax.set_xlabel("")
    ax.set_xlim(-0.5, CLASSES-0.5)
    ax.set_ylim(0, 1)

# %%
#Do this calculation just once
#Normalized prediction arrays for all datasets [hist1, hist2, ...] where hist1 = [a, b, c... d] with sum(hist1)=1
cf_matrix = confusion_matrix(df["Truth"].astype(int), df["Prediction"].astype(int), normalize="true")
print(cf_matrix)
p_estimated = np.array([row[i] for i, row in enumerate(cf_matrix)])
print(p_estimated)
#n_theory = [np.array([((len(theory[theory["Predictions"]==i])/len(theory))) for i in range(CLASSES)]) for theory in datasets]
# Out:
# [[9.40600000e-01 3.88666667e-02 1.78666667e-02 1.20000000e-03
#   4.00000000e-04 1.06666667e-03]
#  [9.18666667e-02 7.71733333e-01 5.53333333e-02 2.60000000e-02
#   4.80000000e-02 7.06666667e-03]
#  [7.98000000e-02 8.16666667e-02 4.27266667e-01 1.47600000e-01
#   1.96333333e-01 6.73333333e-02]
#  [4.25333333e-02 9.67333333e-02 2.92333333e-01 1.73066667e-01
#   3.29200000e-01 6.61333333e-02]
#  [3.22666667e-02 1.12133333e-01 2.38266667e-01 1.69933333e-01
#   3.78666667e-01 6.87333333e-02]
#  [6.53333333e-03 9.66666667e-03 2.93333333e-02 1.20666667e-02
#   2.80666667e-02 9.14333333e-01]]
# [0.9406     0.77173333 0.42726667 0.17306667 0.37866667 0.91433333]

# %%
#Chi2 test
def chi2(n_expected, n_data):
    return(np.sum((n_data-n_expected)**2/(n_expected)))

def chi2_method_pearson(prob_dist, data, classes, verbose=False):

    #Number of classified particles in each class
    N_samp = len(data)
    #Number of predicted events for theory
    N_expected = prob_dist*N_samp
    N_data = np.array([len(data[data["Prediction"]==i]) for i in range(classes)])
    #Calculate chi2_value
    chi2_value=chi2(N_expected, N_data)
    #Number of degrees of freedom
    ndof = classes-1
    #Get the p-value from the chi2
    p_value = np.float64((np.float64(1) - stats.chi2.cdf(chi2_value, ndof)))

    if verbose:
        #if p_value < 10**(-10):
        #print("p value: ", p_value)
        print(f"Histogram for data: {N_data}")
        print(f"Histogram theory: {N_expected}")
        print(f"The chi2 value for theory is {chi2_value}. The p-value is {p_value}")
    
    return p_value

# %%
#poisson test
def poisson(n, l):
    return((l**n)*np.exp(-l)/math.factorial(n))

def poisson_method(prob_dist, data, classes, verbose=False):
    #Number of classified particles in each class
    N_samp = len(data)
    #Number of predicted events for theory
    N_expected = prob_dist*N_samp
    N_data = np.array([len(data[data["Prediction"]==i]) for i in range(classes)])
    
    j_max = np.argmax(N_expected)
    lambda_j = N_expected[j_max]
    n_obs = N_data[j_max]
    p_value = np.sum([poisson(n, lambda_j) for n in range(0, n_obs+1)])

    if verbose:
        print(f"Histogram for data: {N_data}")
        print(f"Histogram theory: {N_expected}")
        print(f"The p value for theory is {p_value}")
        print(f"{lambda_j}")

    return p_value

# %%
# binomial test
def binomial(c, n, p):
    return((math.factorial(n)/(math.factorial(c)*math.factorial(n-c)))*(p**c)*((1-p)**(n-c)))

def binomial_method(hypothesis_index, prob_dist, data, classes, verbose=False):
    #Number of classified particles in each class
    N_samp = len(data)
    #Number of expected events
    N_exp = prob_dist*N_samp
    N_data = np.array([len(data[data["Prediction"]==i]) for i in range(classes)])
    n_obs = N_data[hypothesis_index]
    print(prob_dist[hypothesis_index], n_obs)
    
    p_value = np.sum([binomial(n, N_samp, prob_dist[hypothesis_index]) for n in range(0, n_obs+1)])

    if verbose:
        print(f"Empirical frequencies: {N_data/N_samp}")
        print(f"Expected frequencies: {prob_dist}")
        print(f"The p value for theory is {p_value}")

    return p_value

# %%
#Test experiment 
data_id = 1
theory_id = 3
print(f"Sending in {PLOT_LABELS[data_id]}, testing against {PLOT_LABELS[theory_id]} theory")

N = 20 #number of events
rand_idx = random.sample(range(len(datasets[0])-N_max), N)
experiment = datasets[data_id].iloc[rand_idx]
print("Detected events")
print("..... Pearson chi2 test ....")
p1 = chi2_method_pearson(cf_matrix[theory_id], experiment, CLASSES, verbose=True)
print("..... Poisson test ....")
p2 = poisson_method(cf_matrix[theory_id], experiment, CLASSES, verbose=True)
print("..... Binomial test ....")
p3 = binomial_method(theory_id, cf_matrix[theory_id], experiment, CLASSES, verbose=True)
# Out:
# Sending in BH_n4_M8, testing against BH_n4_M10 theory
# Detected events
# ..... Pearson chi2 test ....
# Histogram for data: [ 2 15  1  1  1  0]
# Histogram theory: [0.85066667 1.93466667 5.84666667 3.46133333 6.584      1.32266667]
# The chi2 value for theory is 101.61312541463569. The p-value is 0.0
# ..... Poisson test ....
# Histogram for data: [ 2 15  1  1  1  0]
# Histogram theory: [0.85066667 1.93466667 5.84666667 3.46133333 6.584      1.32266667]
# The p value for theory is 0.010483431347260687
# 6.584
# ..... Binomial test ....
# 0.17306666666666667 1
# Empirical frequencies: [0.1  0.75 0.05 0.05 0.05 0.  ]
# Expected frequencies: [0.04253333 0.09673333 0.29233333 0.17306667 0.3292     0.06613333]
# The p value for theory is 0.1159367857870631

# %%
np.std([0.5357644634020104, 0.006084989372699726, 0.8415483497839197, 0.8415483497839197, 
        1.0, 0.8415483497839197, 1.0, 0.5357644634020104, 0.09318252258608951])
# Out:
# 0.3501094767410086

# %%
LOAD
# Out:
# True

# %%
#get p-value as a function of number of events
N_list = np.arange(2, N_max, 1) #A list of integers from 2 to N_max

if LOAD:
    #LOAD EXPERIMENT
    df_results = [[0]*CLASSES for i in range(CLASSES)]
    for i in range(CLASSES):
        for j in range(CLASSES):
            df_results[i][j] = pd.read_csv(f"../results/{STATISTIC}/{MODEL_NAME}/m_{M}_truth_{LABELS[i]}_hypothesis_{LABELS[j]}.csv")

else:
    #RUN EXPERIMENT
    df_results = [[0]*CLASSES for i in range(CLASSES)]
    for i in tqdm(range(len(datasets))): #Iterate over all types of pseudodata
        for s, hypothesis in enumerate(cf_matrix): #Iterate over all hypothesis
            df_temp = pd.DataFrame(columns=["N", "average", "min", "max", "std", "5_percentile", "95_percentile"])
            df_temp["N"] = N_list
            avg_temp = np.zeros(len(N_list))
            min_temp = np.zeros(len(N_list))
            max_temp = np.zeros(len(N_list))
            std_temp = np.zeros(len(N_list))
            avg_temp = np.zeros(len(N_list))
            lower_percentile_temp = np.zeros(len(N_list))
            upper_percentile_temp = np.zeros(len(N_list))

            for j, n in enumerate(N_list): # Iterate over number of events detected
                rand_idx = [random.sample(range(len(datasets[0])-N_max), n) for k in range(0, M)]
                experiments = [datasets[i].iloc[rand_idx[k]] for k in range(0, M)] #Generate a list of M number of experiments with n events
                if STATISTIC=="poisson":
                    results = np.array([poisson_method(hypothesis, experiment, CLASSES) for experiment in experiments])
                elif STATISTIC=="chi2":
                    results = np.array([chi2_method_pearson(hypothesis, experiment, CLASSES) for experiment in experiments])
                elif STATISTIC=="binomial":
                    results = np.array([binomial_method(s, hypothesis, experiment, CLASSES) for experiment in experiments])
                else:
                    print("Choose an available statistic.")
                    exit()
                avg_temp[j] = np.average(results, axis=0)
                min_temp[j] = results.min()
                max_temp[j] = results.max()
                std_temp[j] = np.std(results, axis=0)
                lower_percentile_temp[j] = np.percentile(results, 5)
                upper_percentile_temp[j] = np.percentile(results, 95)
            
            df_temp["average"] = avg_temp
            df_temp["min"] = min_temp
            df_temp["max"] = max_temp
            df_temp["std"] = std_temp
            df_temp["5_percentile"] = lower_percentile_temp
            df_temp["95_percentile"] = upper_percentile_temp

            df_results[i][s] = df_temp

# %%
#Save results
if not LOAD:
    if (not os.path.isdir(f"../results/{STATISTIC}/{MODEL_NAME}") ):
            os.mkdir(f"../results/{STATISTIC}/{MODEL_NAME}")
    for i in range(CLASSES):
        for j in range(CLASSES):
            df_results[i][j].to_csv(f"../results/{STATISTIC}/{MODEL_NAME}/m_{M}_truth_{LABELS[i]}_hypothesis_{LABELS[j]}.csv")

# %%
df_results[0][3]
# Out:
#     Unnamed: 0   N   average       min       max       std  5_percentile  95_percentile  25_percentile  75_percentile
# 0            0   2  0.684677  0.683819  0.970048  0.015654           NaN            NaN       0.683819       0.683819
# 1            1   3  0.566774  0.565473  0.920511  0.021459           NaN            NaN       0.565473       0.565473
# 2            2   4  0.469957  0.467608  0.859066  0.030231           NaN            NaN       0.467608       0.467608
# 3            3   5  0.388569  0.386681  0.791318  0.027577           NaN            NaN       0.386681       0.386681
# 4            4   6  0.322570  0.319759  0.721288  0.033477           NaN            NaN       0.319759       0.319759
# ..         ...  ..       ...       ...       ...       ...           ...            ...            ...            ...
# 38          38  40  0.000735  0.000500  0.021761  0.001188           NaN            NaN       0.000500       0.000500
# ...

# %%
sn.scatterplot(df_results[0][3], x="N", y="25_percentile")
# Out:
# <AxesSubplot: xlabel='N', ylabel='25_percentile'>

# %%
#Plot
fig, axs = plt.subplots(ncols = 3, nrows=2, figsize=(15, 10), layout="constrained")
plt.subplots_adjust(hspace=0.25)
for i in range(len(PLOT_LABELS)): #iterate over pseudodata
    axs[i%2][i//2].set_title(f"Data = {PLOT_LABELS[i]}", fontsize=16)
    for k in range(len(PLOT_LABELS)): #iterate over theories
        axs[i%2][i//2].plot(N_list, df_results[i][k]["average"], label=PLOT_LABELS[k], color=paper_colors[k], linewidth=3)
        axs[i%2][i//2].fill_between(N_list, df_results[i][k]["25_percentile"], 
                                    df_results[i][k]["75_percentile"], alpha=0.3, color=paper_colors[k])
        #axs[i%2][i//2].errorbar(N_list, df_results[i][k]["average"], 
        #                        yerr=(abs(df_results[i][k]["average"] - df_results[i][k]["5_percentile"]), 
        #                              df_results[i][k]["average"] + df_results[i][k]["95_percentile"]),
        #                        label=PLOT_LABELS[k], color=paper_colors[k], linewidth=3, elinewidth=1)

for ax in axs.flatten():
    ax.set_yscale("log")
    ax.set_xlabel("Number of events", fontsize=14)
    ax.set_ylabel("p-value", fontsize=14)
    ax.set_xlim(2, N_max-1)
    ax.set_ylim(10**(-3),1.2)
    #ax.legend(loc=4, fontsize=14, ncol=2, frameon=True, framealpha=0.6)
    excl_x = np.linspace(0, 50, 20)
    ax.plot(excl_x, [0.0455]*len(excl_x), color="black", linestyle="--", alpha=0.8)
    ax.tick_params(which="major", direction="out", bottom=True, left=True, pad=5, length=6, width=1, labelsize=12)
    ax.set_xticks(np.arange(0, 45, 5))
    ax.set_xlim(2, 44)

fig.suptitle(f"      ", x=0.1, va="top", fontsize=40)
handles, labels = axs[0][0].get_legend_handles_labels()
#labels = [fr"{hue_key} = {label}" for label in labels]
fig.legend(handles, labels, loc='upper center', ncol=6, labelspacing=0.1, fontsize=16, frameon=True)

fig.savefig(f"../results/figures/{STATISTIC}_M_{M}_Ntest_{TEST_N_EVENTS}_p_values_{PLOT_LABELS[i]}_raw.pdf", format="pdf", bbox_inches='tight')
# Out:
# /tmp/ipykernel_10615/981192486.py:3: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.subplots_adjust(hspace=0.25)

# %%
#Fit a nicer function to the data points
def fit_func(x, a, b, c):
    return (-a*x**2-b*x-c)
 
fig, ax = plt.subplots(ncols = 3, nrows=2, figsize=(21, 17))
plt.subplots_adjust(hspace=0.25)

for i in range(len(PLOT_LABELS)): #iterate over pseudodata
    ax[i%2][i//2].set_title(f"{PLOT_LABELS[i]}")

    for k in range(len(PLOT_LABELS)): #iterate over theories
        y_vals = df_results[i][k]["average"]
        err_down = df_results[i][k]["25_percentile"]
        #Remove stupid values
        y_lower = y_vals-err_down
        x_vals = N_list[y_lower>0]
        err_down = err_down[y_lower>0]
        err_up = df_results[i][k]["75_percentile"]
        err_up = err_up[y_lower>0]
        y_vals = y_vals[y_lower>0]

        if len(y_vals)>0:
            y_params, y_params_covariance = optimize.curve_fit(fit_func, x_vals, np.log(y_vals), p0=[0, 0, 0], method='dogbox')
            err_down_params, err_down_params_covariance = optimize.curve_fit(fit_func, x_vals, np.log(y_vals-err_down), p0=[0, 0, 0], method='dogbox')
            err_up_params, err_up_params_covariance = optimize.curve_fit(fit_func, x_vals, np.log(y_vals+err_up), p0=[0, 0, 0], method='dogbox')
            print(f"Particles in: {PLOT_LABELS[i]}, theory {PLOT_LABELS[k]}")
            print(y_params)

            fit_y_vals = np.exp(fit_func(x_vals, y_params[0], y_params[1], y_params[2]))
            fit_err_down = np.exp(fit_func(x_vals, err_down_params[0], err_down_params[1], err_down_params[2]))
            fit_err_up = np.exp(fit_func(x_vals, err_up_params[0], err_up_params[1], err_up_params[2]))
            #print(fit_y_vals - fit_err_down)
            
            ax[i%2][i//2].plot(x_vals, fit_y_vals, label=PLOT_LABELS[k], color=paper_colors[k], linewidth=3)
            #ax[i%2][i//2].plot(x_vals, fit_err_down, label=PLOT_LABELS[k], color=paper_colors[k], linewidth=2, linestyle="--", alpha=0.8)
            ax[i%2][i//2].fill_between(x_vals, fit_err_down, fit_err_up, alpha=0.3, color=paper_colors[k])
        
        else:
            ax[i%2][i//2].scatter(x_vals, y_vals, label=PLOT_LABELS[k], color=paper_colors[k])

for axis in ax.reshape(-1):
    axis.set_yscale("log")
    axis.set_xlabel("Number of events")
    axis.set_ylabel("p-value")
    axis.set_xlim(2, N_max-1)
    axis.set_ylim(10**(-3), 1)
    axis.legend(loc=4, fontsize=14, ncol=2, frameon=True)
    excl_x = np.linspace(0, 50, 20)
    axis.plot(excl_x, [0.0455]*len(excl_x), color="black", linestyle="--", alpha=0.8)
# Out:
# Particles in: SPH_9, theory SPH_9
# [-0.00023951  0.01799125  0.17314089]
# Particles in: SPH_9, theory BH_n4_M8
# [3.37055652e-04 9.72119435e-01 6.82746846e-01]
# Particles in: SPH_9, theory BH_n2_M10
# [-0.00056843  0.41205708  0.47721471]
# Particles in: SPH_9, theory BH_n4_M10
# [-1.75068466e-04  1.88188360e-01  7.28295384e-03]
# Particles in: SPH_9, theory BH_n6_M10
# [-2.10625616e-04  4.75740854e-01 -1.79132783e-03]
# Particles in: SPH_9, theory BH_n4_M12
# [4.57259655e-04 2.31697820e+00 4.32565834e-01]
# Particles in: BH_n4_M8, theory SPH_9
# [0.00672278 1.4056861  0.53471491]
# Particles in: BH_n4_M8, theory BH_n4_M8
# [-2.03687248e-04  1.39043352e-02  3.63146204e-01]
# Particles in: BH_n4_M8, theory BH_n2_M10
# [-5.09299567e-04  2.85879652e-01  6.46751625e-01]
# Particles in: BH_n4_M8, theory BH_n4_M10
# [-0.00063706  0.12603199  0.22597394]
# Particles in: BH_n4_M8, theory BH_n6_M10
# [-5.58669955e-04  2.55702783e-01  5.73919471e-01]
# ...

# %%
#Save figures for paper

for i in range(len(PLOT_LABELS)): #iterate over pseudodata
    
    fig, ax = plt.subplots(ncols = 1, nrows=1, figsize=(8, 8))
    ax.set_title(f"{PLOT_LABELS[i]}")

    for j in range(len(PLOT_LABELS)): #iterate over theories
        k = PLOT_ORDER[j]
        y_vals = p_values_p[i][k]
        err_down = err_down_values_p[i][k]
        y_lower = y_vals-err_down
        x_vals = N_list[y_lower>0]
        err_down = err_down_values_p[i][k][y_lower>0]
        err_up = err_up_values_p[i][k][y_lower>0]
        y_vals = y_vals[y_lower>0]

        if len(y_vals)>0:
            y_params, y_params_covariance = optimize.curve_fit(fit_func, x_vals, np.log(y_vals), p0=[0, 0, 0], method='dogbox')
            err_down_params, err_down_params_covariance = optimize.curve_fit(fit_func, x_vals, np.log(y_vals-err_down), p0=[0, 0, 0], method='dogbox')
            err_up_params, err_up_params_covariance = optimize.curve_fit(fit_func, x_vals, np.log(y_vals+err_up), p0=[0, 0, 0], method='dogbox')
            #print(f"Particles in: {PLOT_LABELS[i]}, theory {PLOT_LABELS[k]}")
            #print(y_params)

            fit_y_vals = np.exp(fit_func(x_vals, y_params[0], y_params[1], y_params[2]))
            fit_err_down = np.exp(fit_func(x_vals, err_down_params[0], err_down_params[1], err_down_params[2]))
            fit_err_up = np.exp(fit_func(x_vals, err_up_params[0], err_up_params[1], err_up_params[2]))
            #print(fit_y_vals - fit_err_down)
            
            ax.plot(x_vals, fit_y_vals, label=PLOT_LABELS[k], color=paper_colors[k], linewidth=3)
            #ax[i%2][i//2].plot(x_vals, fit_err_down, label=PLOT_LABELS[k], color=paper_colors[k], linewidth=2, linestyle="--", alpha=0.8)
            ax.fill_between(x_vals, fit_err_down, fit_err_up, alpha=0.3, color=paper_colors[k])
        
        else:
            ax.scatter(x_vals, y_vals, label=PLOT_LABELS[k], color=paper_colors[k])

    ax.set_yscale("log")
    ax.set_xlabel("Number of events")
    ax.set_ylabel("p-value")
    ax.set_xlim(2, N_max-1)
    ax.set_ylim(10**(-3), 1)
    ax.legend(loc=4, fontsize=14, ncol=2, frameon=True)
    excl_x = np.linspace(0, 50, 20)
    ax.plot(excl_x, [0.0455]*len(excl_x), color="black", linestyle="--", alpha=0.8)

    fig.savefig(f"../results/figures/{STATISTIC}_M_{M}_Ntest_{TEST_N_EVENTS}_p_values_{PLOT_LABELS[i]}.pdf", format="pdf", bbox_inches='tight')
# Out:
# /home/agrefsru/.conda/envs/imcal/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/agrefsru/.conda/envs/imcal/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/agrefsru/.conda/envs/imcal/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/agrefsru/.conda/envs/imcal/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
